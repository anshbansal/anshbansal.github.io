# %% [markdown]
# # Lesson 02 - Design Principles
#
# ## Lesson Overview
# - Next goal in this course is to re-create a visualization to improve it
# - learn about design principles that helps
#     - to enhance the graphic
#     - to prototype
# - refine a design
# - metrics to measure their effectiveness
# - various charts and bars that can be used
# - theory about how to make that selection
#
# ## Visual Encodings
# - visual encodings are the building blocks using which we create graphics
#
# ## Chart Types
# - [Selecting the Right Graph for Your Message](http://www.perceptualedge.com/articles/ie/the_right_graph.pdf) by Stephen Few
# - Cole shares her thoughts on the [Chart Chooser](http://www.storytellingwithdata.com/2013/04/chart-chooser.html).
# - Juice Labs provides an [interactive form of the Chart Chooser](http://labs.juiceanalytics.com/chartchooser/index.html). You can also download Excel or PowerPoint templates of the chart types from the site.
# - [Larger image of Chart Suggestions](https://apandre.files.wordpress.com/2011/02/chartchooserincolor.jpg) - A Thought Starter (modified with permission by Doug Hall)
#
# ## Visualizations in Data Science
# - Data artist or a journalist may be interested in complex graphic to convey all information
# - Data scientist's first priority is to have simple solutions to solve problems
# - Inspect the data - types, variations, and choose the right tool
#
# ## Chart types
# - Chart types are just visual encodings applied to data types and some relationships between those data
# ![](chart_types1.png)
# ![](chart_types2.png)
# - In case of scatter plot the x values are considered independent of each other. If they were dependent on each other and have an order then it is probably better to use line chart

# %% [markdown]
# ## Small Multiples
# - Series of plots arranged together faceted by a category
# ![](chart_types3.png)
#
# ## Line Plot
# ![](chart_types4.png)
#
# For proportions or comparisons grouped bar charts

# %% [markdown]
# * Stephen Few's article on [Selecting the Right Chart Type](http://www.perceptualedge.com/articles/ie/the_right_graph.pdf)
# * Stephen Few's [Graph Selection Matrix](http://www.perceptualedge.com/articles/misc/Graph_Selection_Matrix.pdf)
# * Andrew Abela's [Chart Suggestions](http://www.extremepresentation.com/uploads/documents/choosing_a_good_chart.pdf)
# * Solomon Messing's [When to use stacked bar charts?](http://solomonmessing.wordpress.com/2014/10/11/when-to-use-stacked-barcharts/)
# * Box Plots [explained](http://www.physics.csbsju.edu/stats/box2.html)
# * Plotly: [U.S. Unemployment](https://plot.ly/~Jay-Oh-eN/1)
# *  To find out more about stacked and grouped bar charts, see [How Groups Stack Up: When to Use Grouped vs Stacked Column Charts](http://blog.visual.ly/how-groups-stack-up-when-to-use-grouped-vs-stacked-column-charts/). Noah Lorang's [Three charts are all I need](https://signalvnoise.com/posts/3388-three-charts-are-all-i-need)
#
#
# ### Chart Relationships
# * bar chart - highlights individual values, supports comparisons, and can show rankings or deviations
# * boxplot - shows distributions and quantiles, especially useful when comparing distributions
# * pie chart - shows part-to-whole relationship and best suited for one category; poor for making comparisons
# * stacked bar chart - shows part-to-whole relationship and best suited for showing composition within categories and totals
# * bubble chart - shows how three or more sets of values vary; shows correlation
# * line chart - shows overall changes and patterns, usually over equally spaced intervals of time
# * map - values are encoded on physical locations and patterns may be drawn by comparing locations
# * scatterplot - shows how two pair sets of values (for example height and shoe size) vary; shows correlation
# * tables - work well when there is no inherent relation between the data you are conveying
#
#
# The below is a map of the United states. Each dot represents a person and the color represents their race. The x and y position are chosen based on the block from which they reported in census
# ![](racial_map.png)
#
# ### Geographic Charts
# * choropleth = geographic + color
# * cartogram = geographic + size
# * dot map = geographic + shape
#
# ### Additional Chart types
# * [Common Chart Types](http://guides.library.duke.edu/vis_types) from Duke Introduction to Data Visualization Guide
# * [Racial Dot Map](http://www.coopercenter.org/demographics/Racial-Dot-Map) by Dustin Cable
# * [Choropleth Map](http://en.wikipedia.org/wiki/Choropleth_map)
# * [Cartogram](http://en.wikipedia.org/wiki/Cartogram)
# * [A Tour through the Visualization Zoo](http://queue.acm.org/detail.cfm?id=1805128) by Jeff Heer, Mike Bostock, and Vadim Ogievetsky
#
# * [Bullet Graph](http://www.perceptualedge.com/articles/misc/Bullet_Graph_Design_Spec.pdf) - Stephen Few developed the bullet graph to replace meters and gauges that often fill too much valuable space on dashboards. You can read more about bullet graphs on wikipedia.
# * [Sparklines](http://www.edwardtufte.com/bboard/q-and-a-fetch-msg?msg_id=0001OR) - Edward Tufte invented these bit-sized graphics to pack a punch of information in a small chart area. A reader can quickly see historical trends, anomalies, and the current status of a metric by viewing a sparkline. You can read more about sparklines on wikipedia.
# * [Cycle Plots](http://www.perceptualedge.com/articles/guests/intro_to_cycle_plots.pdf) - Originally created by Cleveland, Dunn, and Terpenning in 1978, cycle plots offer a way to investigate time series data in a different way than conventional line charts.
# * [Connected Scatter Plots](http://www.thefunctionalart.com/2012/09/in-praise-of-connected-scatter-plots.html) - Think back to the Gapminder data visualization. Could you reveal the same patterns in the data over the years without animation? Alberot Cairo says "Yes!". Alberto praises connected scatter plots and shares examples of them on his blog, The Functional Art.
# * [Violin Plots](http://en.wikipedia.org/wiki/Violin_plot) - Violin plots are similar to box plots, except that they show the probability density of the data at different values. Nathan Yau describes violin plots and other ways to visualize and compare distributions on his blog Flowing Data.

# %% [markdown]
# ## Pre attentive Processing
# Try and count number of times 9 appears in below two. Which one is faster to count?
# ![](digits.png)
#
# * Pre-attentive processing takes about 200 to 250 ms
# * Taps into our automatic processes of vision and perception
# ![](pre_attentive_attributes.png)
#
# * [Processes that Pop Out](http://www.infovis.net/printMag.php?num=179&lang=2) by Juan C. Dursteler
# * [Tapping the Power of Visual Perception](http://www.perceptualedge.com/articles/ie/visual_perception.pdf) by Stephen Few
# * [Information Visualization: Perception for Design](http://www.amazon.com/Information-Visualization-Third-Edition-Technologies/dp/0123814642) by Colin Ware

# %% [markdown]
# ## Negative Space
# ![](negative1.png)
# You can see a vase or 2 people facing each other
#
# ![](negative2.png)
# The arrow reinforces the company's goal as a shipping service
#
# * https://discussions.udacity.com/t/lesson-2a-negative-spaces-dand/25150
# * https://discussions.udacity.com/t/negative-spaces/16154
#
# * [How Google Uses White Space](http://us1.campaign-archive2.com/?u=836dc9c64862f158af8a31e20&id=fdcffdbf91)
# * [Designing with White Space: Why 1 + 1 = 3?](http://designforhackers.com/blog/whitespace-113/)

# %% [markdown]
# ## Cholera Map
# https://upload.wikimedia.org/wikipedia/commons/2/27/Snow-cholera-map-1.jpg
# ![](cholera.png)ar
#
# * Deaths of people were mapped by John Snow.
# * There were no deaths around brewery because it gave its workers unlimited beer allowance to its workers. The fermentation process killed the cholera virus and hence no deaths.
# * Looking at the graph it is possible to see that all deaths were in a particular region. What was common? A pump with contaminated water
# * [John Snow and the Broad Street Pump](http://www.ph.ucla.edu/epi/snow/snowcricketarticle.html)
# * [Gay Rights in the United States as of May 2012 by the Guardian](http://www.theguardian.com/world/interactive/2012/may/08/gay-rights-united-states)
#
# ## Careful with Colors
# - Get things right with black and white
# - Use less intense colors (Medium Hues or Pastels)
# - Use color to highlight
# - Sometimes, double encodings can be helpful like in the [Facebook IPO graphic](http://www.nytimes.com/interactive/2012/05/17/business/dealbook/how-the-facebook-offering-compares.html?_r=1&). The scatter plot is a more complex graphic so the double encodings, such as color and position along the x-axis, help the reader make sense of the data.
# - [Rules for Using Color](http://www.perceptualedge.com/articles/visual_business_intelligence/rules_for_using_color.pdf) by Stephen Few
#
# - High contrast between text and background is best for reading tabular data
# - A sequential color palette is a good choice for encoding the sales of a business
# ![](palette.png)
# - Dark/Bright colors work well for coloring small points in scatterplots.
# - Pastels work well for coloring large points in scatterplots. Can be used for smaller points by enlarging all of them
# - 3D effects and shadows can distract from the data and make it harder to interpret the data
# - Stephen Few prefers to call diverging color palettes "dual-ordered palettes."
#
# - http://gvi.seas.harvard.edu/sites/all/files/infovis2011_slides.pdf   (infovis slides - easy read)
# - http://gvi.seas.harvard.edu/sites/all/files/borkin-InfoVis2011_camera-ready.pdf (research paper - more dense)
# - [Data Visualization Experts Propose Simpler Approach to Diagnosis](http://phys.org/news/2011-10-heart-disease-visualization-experts-simpler.html)
# - [Rainbow Color Map (Still) Considered Harmful](http://www.rkriz.net/Projects//create_color_table/color_07.pdf)
#
# ## Correcting Colors
# - Daniel Huffman's [Cartastrophe](http://cartastrophe.wordpress.com/)
# - Cynthia Brewer's [ColorBrewer](http://colorbrewer2.org/)
# - [Choosing Color Palettes Part 1](http://www.r-bloggers.com/choosing-colour-palettes-part-i-introduction/) (R Bloggers)
# - [Choosing Color Palettes Part 2](http://www.r-bloggers.com/choosing-colour-palettes-part-ii-educated-choices/) (R Bloggers)
# - Color Blind Palettes http://www.cookbook-r.com/Graphs/Colors_(ggplot2)/

# %% [markdown]
# ## Gestalt Principles of Perception
# Many of these principles play an important role in choosing visual encodings and creating a hierarchy of information in a graphic
# - [The Gestalt Laws of Perception](http://www.slideshare.net/luisaepv/the-gestalt-laws-of-perception)
# - [Gestalt Principles for Data Visualization](http://emeeks.github.io/gestaltdataviz/section1.html) (Similarity, Proximity, and Enclosure)
# - [The Gestalt Principles](http://graphicdesign.spokanefalls.edu/tutorials/process/gestaltprinciples/gestaltprinc.htm)
# - [Gestalt Design Notes](http://jimsaw.com/design/gestalt.html)

# %% [markdown]
# ## Chartjunk
# - Important to decide what you will leave out
# - heavy or dark grid lines
# - unnecessary text
# - ornamentated chart axes
# - pictures within graphs
# - shading or 3D perspective
# ![](chartjunk.png)
#
# ## Less is more
# ![](less_is_more.png)
#
# ## Data Ink Ratio
#
# data ink ratio = (ink used to describe data) / (ink used to describe everything else)
#
# - high data to ink ratio is considered good
#
# ![](data_ink_ratio1.png)
#
# - Let's improve data to ink ratio of a visualization
# ![](improve_data_to_ink1.png)
# ![](improve_data_to_ink2.png)
# ![](improve_data_to_ink3.png)
# ![](improve_data_to_ink4.png)
# ![](improve_data_to_ink5.png)
# ![](improve_data_to_ink6.png)
# ![](improve_data_to_ink7.png)
# ![](improve_data_to_ink8.png)
#
# Compare it with the first one
# ![](improve_data_to_ink1.png)

# %% [markdown]
# ## Lie Factor
# lie factor = (size of the effect shown in the graphic) / (size of the effect shown in the data)
#
# A graph with `0.95 < lie factor < 1.05` has high integerity
#
# ## Grammar of Graphics
# - Hadley Wickham's [A Layered Grammar of Graphics](http://vita.had.co.nz/papers/layered-grammar.html)
# - separating aesthetic (e.g. line) from the data itself
# - It is quite an extensive theory which has influenced the development of graphics and visualization libraries alike (including D3 and its precursors), but in this class you will focus on 3 of its key principles:
#     - Separation of data from aesthetics
#     - Definition of common plot/chart elements
#     - Composition of these common elements
